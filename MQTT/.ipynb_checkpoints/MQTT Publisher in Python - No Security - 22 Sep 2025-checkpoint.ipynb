# %% [markdown]
# | Libaray               | Version   |
# |-------------------------|-----------|
# | paho.mqtt                | V2.1.0   |
#
# _Last code updated on: 22 September 2025_

# %% [markdown]
# ## Tested with Mosquitto MQTT Broker

# %% [markdown]
# ## Install MQTT Library if not installed

# %%
# !python -m pip install paho.mqtt

# %% [markdown]
# ## Import Functions from Library to Make Publisher

# %%
import paho.mqtt.client as paho
# %config Completer.use_jedi = False
import time
import random

# %% [markdown]
# ## Define Perameter for Publisher

# %%
broker = "localhost"
port = 1883

# %% [markdown]
# ## Establish Connection

# %%
publisher = paho.Client(client_id="MQTT PYTHON PUBLISHER")

# %%
publisher.connect(broker,port)

# %% [markdown]
# ## Update Topic Value Continuous

# %%
Value = 0
while True:
    publisher.publish("house/Room_Temp_1",Value)
    publisher.publish("house/Room_Temp_2",Value+2)
    #print("Please check data on your Subscriber Code \n")
    time.sleep(1)
    Value = random.randint(25, 45)
